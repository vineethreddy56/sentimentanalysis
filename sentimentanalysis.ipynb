# %% [markdown]
# <a href="https://colab.research.google.com/github/vineethreddy56/sentimentanalysis/blob/main/sentimentanalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyforest
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyforest: filename=pyforest-1.1.2-py2.py3-none-any.whl size=15902 sha256=4746ae99dac06c36a255bc05b3bcdae8c4bd6d1cf6822e4aafb190bfc5607098
#   Stored in directory: /root/.cache/pip/wheels/66/4f/3c/cbdf5336b5a84f39cb6e3d76eecb9acf3f99a2c072785afecc
# Successfully built pyforest
# ...

# %%
import pyforest

# %%
df=pd.read_csv("IMDB-Dataset.csv")

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df.shape
# Out:
# (50000, 2)

# %%
df=df.head(1000)

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
def clean_text(text):
    text = re.sub(r'<br\s*/?>', ' ', text)
    text = re.sub(r'[^a-zA-Z ]', '', text)
    return text.lower()
df['review']=df['review'].apply(clean_text)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(df['review'],df['sentiment'],test_size=0.2,random_state=42)

# %%
vectorizer=TfidfVectorizer(max_features=1000)
X_train_tfidf=vectorizer.fit_transform(X_train)
X_test_tfidf=vectorizer.transform(X_test)

# %%
model=LogisticRegression(max_iter=100)
model.fit(X_train_tfidf,Y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(X_test_tfidf)

# %%
from sklearn.metrics import accuracy_score,classification_report
print(accuracy_score(Y_test,y_pred))
# Out:
# 0.83

# %%
print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.84      0.84      0.84       104
#     positive       0.82      0.82      0.82        96
#
#     accuracy                           0.83       200
#    macro avg       0.83      0.83      0.83       200
# weighted avg       0.83      0.83      0.83       200

# %%
def predposneg(tex):
  tex=clean_text(tex)
  tex=vectorizer.transform([tex])
  res=model.predict(tex)
  print(res)
predposneg("not liked the movie")
# Out:
# ['negative']
